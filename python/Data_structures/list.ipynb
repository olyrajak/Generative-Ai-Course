# %% [markdown]
# # List

# %% [markdown]
# ## List are one of the type of data strutured which are used for storing your data in a strutured format where you can store data of any  data type and that as it is one of the data structure so we can access to the data as well that we are going to store into the list and we can apply crud operation as well i.e create , read , update , delete operations as well

# %%
a=list()

# %%
type(a)
# Out:
# list

# %%
lists=[1,2,3,4,5]

# %%
print(lists)
# Out:
# [1, 2, 3, 4, 5]

# %%
lists_variables=["A","B","C","D",7,6.7,True]

# %%
print(lists_variables)
# Out:
# ['A', 'B', 'C', 'D', 7, 6.7, True]

# %%
''' By using this data strutures we can apply thr crud operation like inserting the data , deleting , updating and reading
'''
lists=["Oly",24,3,4,5,6.7,True]

# %%
print(lists)
# Out:
# ['Oly', 24, 3, 4, 5, 6.7, True]

# %% [markdown]
# # Read a specific data
# ## Lists are ordered and are a  mutable data struture

# %% [markdown]
# ## List Indexing

# %%
 ## By uisng the proper indexing value we can retrive the data from our lists
 print(lists[0])  # This will print the first element of the list
 print(lists[1])  # This will print the second element of the list
# Out:
# Oly
# 24

# %%
# length
print(len(lists))  # This will print the length of the list
# Out:
# 7

# %%
## Length of a data struture is going to the total items having in that data struture 
lists[6]
# Out:
# True

# %%
lists=["Mango","Banana","Grapes","Apple","Guava","Pineapple"]

# %%
print(lists[5])
# Out:
# Pineapple

# %%
print(lists[2])  # This will print the third element of the list
# Out:
# Grapes

# %%
# Negative indexing in python is used to access the elements of a list from the end. The last element of the list has an index of -1, the second last element has an index of -2, and so on.----> In any data structure that we can acces data negative index as well as positive index.
print(lists[-1])  # This will print the last element of the list
print(lists[-2])  # This will print the second last element of the list
# Out:
# Pineapple
# Guava

# %%
# for having the access for all of the values you are going to stoe inside the list you can use this :
print(lists[:])
# Out:
# ['Mango', 'Banana', 'Grapes', 'Apple', 'Guava', 'Pineapple']

# %% [markdown]
# ## List Slicing

# %% [markdown]
# #### List slicing can help us out with retriving a specific data points from out list ---->

# %%
lists[1:4]
# Out:
# ['Banana', 'Grapes', 'Apple']

# %%
lists[1:3]
# Out:
# ['Banana', 'Grapes']

# %%
print(lists[:])
# Out:
# ['Mango', 'Banana', 'Grapes', 'Apple', 'Guava', 'Pineapple']

# %%
# Reverse ----> pineapple, guava, apple, grapes, banana, mango
print(lists[::-1])  # This will print the list in reverse order
# Out:
# ['Pineapple', 'Guava', 'Apple', 'Grapes', 'Banana', 'Mango']

# %%
vegetables=["Potato","Tomato","Onion","Carrot","Cabbage"]
print(vegetables[:])
# Out:
# ['Potato', 'Tomato', 'Onion', 'Carrot', 'Cabbage']

# %%
vegetables[1]
# Out:
# 'Tomato'

# %%
vegetables[0]
# Out:
# 'Potato'

# %%
vegetables[3:4]
# Out:
# ['Carrot']

# %%
vegetables[2:4]
# Out:
# ['Onion', 'Carrot']

# %%
vegetables[3:]
# Out:
# ['Carrot', 'Cabbage']

# %% [markdown]
# ## List are mutable

# %% [markdown]
# #### By mentioning that lists are mutable mean to say that we can replace the values present at a specific location inside our lists

# %%
lists[2]
# Out:
# 'Grapes'

# %%
lists[2]="Strawberry"

# %%
lists[2]
# Out:
# 'Strawberry'

# %%
list_item=[1,5,7,8,"Oly",True,6.7,"apple","Potato"]

# %%
for i in list_item:
    print(i)
# Out:
# 1
# 5
# 7
# 8
# Oly
# True
# 6.7
# apple
# Potato

# %%
# List Slicing
list_item[2:]
# Out:
# [7, 8, 'Oly', True, 6.7, 'apple', 'Potato']

# %%
lists[::2]
# Out:
# ['Mango', 'Strawberry', 'Guava']

# %%
list_item[::2]
# Out:
# [1, 7, 'Oly', 6.7, 'Potato']

# %%
list_item[::3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 lists_item[::3]
#
# NameError: name 'lists_item' is not defined

# %%
list_item[::3]
# Out:
# [1, 8, 6.7]

# %%
list_item[::-2]
# Out:
# ['Potato', 6.7, 'Oly', 7, 1]
