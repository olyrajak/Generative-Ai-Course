# %% [markdown]
# # Data structure in Python

# %% [markdown]
# ### Data structures in python are being huged for storing the data in a astructured format so that we an access the data and along with that we can peform all of the operations with dthese data strutures that we can perform in the case of datbases as well like crud (create , read , update , delete) operation

# %% [markdown]
# ## Types of data struture in python are :
#
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# ## The different types of data strutures deffers on this basis that in which specific format we want to store our data
