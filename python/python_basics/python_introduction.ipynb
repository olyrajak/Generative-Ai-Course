# %% [markdown]
# # What is Python Language ?

# %% [markdown]
# ## Python is the type of programming language which we can use  for communicating with computers or technology

# %% [markdown]
# ## Syntax for Python Language

# %% [markdown]
# syntax reffer to the set of rules that define the combination of symbols that defines combinations of symbol that are consider to be correctly structured programs in a language

# %% [markdown]
# ## Symentic of Python language

# %% [markdown]
# ## Symentic of pyhton language is refers to or interpetition of symbols characters and commands in  a Language.It is about what the code is support to do when it runs.

# %% [markdown]
# # Python syntax rules

# %% [markdown]
# ## 1. Python is Case sensetive

# %%
name="Amit"
Name="Amit"
name==Name
# Out:
# True

# %%
name="Amit"
Name="amit"
name==Name
# Out:
# False

# %% [markdown]
# # Identification Of Python

# %% [markdown]
# ## Other Programming Language {}  for grouping of statement.
# ## But in python we use indention for proper grouping of statement as the proper arrangements of statements with proper spacing int he statements within a block

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
else:
    print("You are not an adult.")
# Out:
# You are an adult.

# %%
1+1+3+5
# Out:
# 10

# %%
1+2+3+5+\
    6+7
# Out:
# 24

# %% [markdown]
# ## Line Continuation ---> We can use back slash for continueing the statement on the next line
# ## for example 1+2+3+5+\
# ## 6+7

# %% [markdown]
# ## Multiple statement in single line in Python

# %%
a=5
b=6
c=a*b

# %%
a=5
b=6
c=a*b

# %%
a=5
b=6
c=a*b
print(c)
# Out:
# 30

# %%
a=5 ; b=6 ; c=a*b ;print(c)
# Out:
# 30
