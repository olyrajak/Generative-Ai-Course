# %% [markdown]
# # Keywords

# %% [markdown]
# Keywords are the reserved words which can't be used as a variable name as they are having a reserved meaning already in python

# %%
list="Oly mpics"
print(list)
# Out:
# Oly mpics

# %%
tuple
# Out:
# tuple

# %%
# when vairable call without assign then it throw error but if already this is keyword then not throw error
