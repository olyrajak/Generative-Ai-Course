# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in python that can be used for storing data into into it or values into itor they can be refferered as container as well.
# ## variables as per its  name , data can vary that we are going to  store into it  once we have declare a variable we can vary the value stored into it

# %%
age = 23
Name = 'Oly'
Height =5.11
is_true =True

# %%
age
# Out:
# 23
