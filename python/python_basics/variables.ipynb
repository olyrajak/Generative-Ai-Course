# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in python that can be used for storing data into  it or values into it or they can be refferered as container as well.
# ## variables as per its  name , data can vary that we are going to  store into it  once we have declare a variable we can vary the value stored into it

# %%
age = 23
Name = 'Oly'
Height =5.11
is_true =True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.11

# %% [markdown]
# # print()

# %% [markdown]
# ## print() ---> print function is be used to represent the value that we are going to store inside it

# %%
print(age)
# Out:
# 23

# %%
print(Name)
# Out:
# Oly

# %%
print("Name is :", Name, "Age is :", age, "Height is :", Height, "Is True :", is_true)
# Out:
# Name is : Oly Age is : 23 Height is : 5.11 Is True : True

# %% [markdown]
# ## Comment
# ## Comment is the statement in a program that we dont want the interperter to execute
# ## interpreter --> Ececute the code by line by line in python language
# ## compiler --> it executes the code completely

# %%
# Hello I am explaining about how to writes comments in python

# %%
# Hello everyone

# %%
'''
Hello everyone, I am explaining about how to write comments in python.
In python we can write comments in two ways. First is single line comment and second is multi
'''
# Out:
# '\nHello everyone, I am explaining about how to write comments in python.\nIn python we can write comments in two ways. First is single line comment and second is multi\n'

# %% [markdown]
# # Variable Naming Convention

# %%
''' Variable names must be Descriptive: 
Naming properly
for example if age this must store age
Age=23
Name='Oly'


'''
# Out:
# " Variable names must be Descriptive: \nNaming properly\nfor example if age this must store age\nAge=23\nName='Oly'\n\n\n"

# %%
'''
They must start with a letter or underscore, but cannot start with a number.
'''
# Out:
# '\nThey must start with a letter or underscore, but cannot start with a number.\n'

# %%
name1="Oly"

# %%
_name="Jaya"

# %%
'''
Variables are also case sensitive, meaning that age, Age and AGE are three different variables.
'''
# Out:
# '\nVariables are also case sensitive, meaning that age, Age and AGE are three different variables.\n'

# %%
name==name1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 name==name1
#
# NameError: name 'name' is not defined

# %%
Name="Oly"
Age=18
Height=5.11

# %%
name==Name
# Out:
# False

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(Name))
# Out:
# <class 'str'>

# %%
print(type(Age))
# Out:
# <class 'int'>

# %%
print(type(Height))
# Out:
# <class 'float'>

# %%
Age=str(Age)
print(type(Age))
# Out:
# <class 'str'>

# %%
 name=int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 name=int(name)
#
# ValueError: invalid literal for int() with base 10: 'jaya'

# %%
'''
Every casting is not possible to convert int to str  posible but strint to int not possible 
'''
# Out:
# '\nEvery casting is not possible to convert int to str  posible but strint to int not possible \n'

# %% [markdown]
# # input()
# ## input() funtion can take the input from the user side and then can store that input into a variable

# %%
Name=input("Enter your name : ")

# %%
print(Name)
# Out:
# Jaya

# %% [markdown]
# ## input function only take the input ina string format until and unless we are not going to exlicitly take the input in integer or other format

# %%
AGE=input("Enter Your Age : ")

# %%
print(AGE)
# Out:
# 22

# %%
print(type(AGE))
# Out:
# <class 'str'>

# %%
height=float(input("Enter your height : "))
print(type(height))
# Out:
# <class 'float'>

# %%
value=bool(input("Enter your value : "))
print(type(value))
print(value)
# Out:
# <class 'bool'>
# True

# %%
value
# Out:
# True

# %%
value
# Out:
# True

# %%
value_user=bool(input("Enter your value : "))

# %%
value_user
# Out:
# True

# %%
## building a simple calculator

value_1=int(input("Enter your first value : "))
value_2=int(input("Enter your second value : "))
sum=value_1+value_2
print("Sum of two values is :", sum)
print("Subtraction of two values is :", value_1-value_2)
print("Multiplication of two values is :", value_1*value_2)
print("Division of two values is :", value_1/value_2)
# Out:
# Sum of two values is : 33
# Subtraction of two values is : 27
# Multiplication of two values is : 90
# Division of two values is : 10.0
