# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of the data that tells the compiler or interpreter that what kind of values we can store into a variable and how much amount of memory will be comsumed to store the data  and then the kind of operation it can perform

# %%
age=input("Enter the age")

# %%
age
# Out:
# '19'

# %%
type(age)
# Out:
# str

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age
# Out:
# '19'

# %%
age2=26

# %%
print(age2)
# Out:
# 26

# %%
print(age+age2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(age+age2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age=int(input("Enter the age"))

# %%
print(age2+age)
# Out:
# 81

# %%
age=int(input("Enter your age : "))

# %%
age2="Hello"

# %%
print(age+age2)
# Out:
# 66Hello

# %%
a=str()

# %%
type(a)
# Out:
# str

# %%
str.capitalize(a)
# Out:
# ''

# %%
a="oly"

# %%
str.capitalize(a)
# Out:
# 'Oly'

# %%
float.from_number(age)
# Out:
# 44.0

# %% [markdown]
# # Different Types of data types in python

# %% [markdown]
# ## 1 int
# ## 2. str
# ## 3. bool
# ## 4. float

# %%
a=23
type(a)
# Out:
# int

# %%
b="Oly"
type(b)
# Out:
# str

# %%
c=33.66
type(c)
# Out:
# float

# %%
is_true=True
type(is_true)
# Out:
# bool

# %%
a=7
b=7

a==b
# Out:
# True

# %%
a=34
b=29
a==b
# Out:
# False
