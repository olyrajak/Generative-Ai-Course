# %% [markdown]
# # Python Requirements

# %% [markdown]
# ## We are going to cover python requirements

# %% [markdown]
# print("Oly")

# %% [markdown]
# print("Hello World !")

# %%
# Out:
# Running cells with 'venv (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Generative Ai Course\python\venv ipykernel --update-deps --force-reinstall'

# %%
print("Oly")
print("Hello World!")
# Out:
# Oly
# Hello World!
