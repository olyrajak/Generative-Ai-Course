# %% [markdown]
# # Conditional Statement

# %% [markdown]
# ### Conditional statement works like real life scenarip where if a certain condition is meeting then a statement of code or block of code gets executed

# %%
print("Hello")
# Out:
# Hello

# %%
# Elegibility for driving or meeting a certain condition
## Condition statement are like the the if statement where if a condition is meeting 
## then a block of code gets executed

age=int(input("Enter your age value : "))
if age >= 18 :
    print("Yes you are elegeble for driving")
else :
    print("Sorry you are not elegeble for driving")
# Out:
# Yes you are elegeble for driving

# %% [markdown]
# #### Conditional Statement
# #### if Statement
# #### elif Statement
# #### else Statement

# %%
## Figure Out who is the tallest amound the 3 friends
oly_height=int(input("Enter your height Oly:"))
noel_height=int(input("Enter Your Height  Noel: "))
riya_height=int(input("Enter Your Height  Riya: "))
bisheswar_height=int(input("Enter Your Height Bisheswar : "))

if oly_height > noel_height > riya_height > bisheswar_height :
    print("Oly Is taller than All")
elif noel_height > oly_height > riya_height > bisheswar_height:
    print("Noel Is taller than All")
elif riya_height > oly_height > noel_height > bisheswar_height:
    print("Riya Is taller than All")
else:
    print("Bisheswar Is taller than All")
# Out:
# Riya Is taller than All

# %% [markdown]
# # Nested Conditional Statement

# %% [markdown]
# ## Nested Contional Statements involve if statement inside another if statement

# %%
## Compare the height of 3 friend
noel_height=int(input("Enter Your Height  Noel: "))
riya_height=int(input("Enter Your Height  Riya: "))
bisheswar_height=int(input("Enter Your Height Bisheswar : "))

if noel_height > riya_height :
    if riya_height>bisheswar_height or noel_height > bisheswar_height:
        print("Noel is the tallest")
elif riya_height>noel_height:
    if riya_height>bisheswar_height or noel_height > bisheswar_height:
            print("Riya is the tallest")
else :
    print("Bisheswar Is tallest")
# Out:
# Riya is the tallest

# %%
# Leap Year or not
# wheather if current year is leap year or not 
year = int(input("Enter the year value"))
if year%4 == 0:
    if  year%100==0:
        if year%400==0 :
            print("Current year is a leap year") 
        else:
            print("Current Year is not leap year")
    else:
            print("Current Year is leap year")
else:
     print("Current Year is not leap year")
# Out:
# Current Year is leap year
