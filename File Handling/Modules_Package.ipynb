# %% [markdown]
# # Modules and Packages

# %%
def addition(num1 ,num2):
    return num1+num2

# %%
addition(2,5)
# Out:
# 7

# %% [markdown]
# ### I want to use logic of the function in this file into the other files

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
#### How to complex the logic of a square root function is going to be

# %% [markdown]
# ## Module
#
# #### A module in pyhton is simply a file containing python code (Funtion , Classes or variables ) that can be imported and used in other programs

# %% [markdown]
# ### Numpy ---> Numpy Module is going to help us with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operation with our array a bit more faster as compared to those of the list
#
# ### ----> We can do it in numpy just because Numpy is having the collection of function and attribute which can help us to word effectienty with the array
